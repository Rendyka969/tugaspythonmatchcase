# %% [markdown]
# <a href="https://colab.research.google.com/github/Rendyka969/tugaspythonmatchcase/blob/main/tugas_match.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kode = "A01"
match kode:
    case "A01":
        nama = "snack"
        harga = 10000
        print(nama, harga)
    case "A02":
        nama = "minuman"
        harga = 8000
        print(nama, harga)
    case "B01":
        nama = "mie instan"
        harga = 3000
        print(nama, harga)
    case "B02":
        nama = "sabun"
        harga = 5000
        print(nama, harga)
    case "C01":
        nama = "shampo"
        harga = 12000
        print(nama, harga)
# Out:
# snack 10000
